# %%
import numpy as np
import pandas as pd

temp = pd.read_csv("C://Users/ARPIT/Desktop/titanic/titanic_train.csv")
temp
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
temp.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
temp.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
temp2 = temp.copy()
temp2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
del temp2["Name"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17372/43614661.py in <module>
# ----> 1 del temp2["Name"]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    3961             # there was no match, this call should raise the appropriate
#    3962             # exception:
# -> 3963             loc = self.axes[-1].get_loc(key)
#    3964             self._mgr = self._mgr.idelete(loc)
#    3965
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Name'

# %%
temp2.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
del temp2["Ticket"]

temp2.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
def a(n):
    if n == "male":
        return 1
    else:
        return 0


temp2["gender"] = temp2.Sex.apply(a)

temp2.head(9)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
# 5            6         0       3    male   NaN      0      0   8.4583   NaN
# 6            7         0       1    male  54.0      0      0  51.8625   E46
# 7            8         0       3    male   2.0      3      1  21.0750   NaN
# 8            9         1       3  female  27.0      0      2  11.1333   NaN
#
#   Embarked  gender
# 0        S       1
# 1        C       0
# 2        S       0
# 3        S       0
# 4        S       1
# 5        Q       1
# 6        S       1
# 7        S       1
# 8        S       0

# %%
del temp2["Sex"]
temp2.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare Cabin Embarked  \
# 0            1         0       3  22.0      1      0   7.2500   NaN        S
# 1            2         1       1  38.0      1      0  71.2833   C85        C
# 2            3         1       3  26.0      0      0   7.9250   NaN        S
# 3            4         1       1  35.0      1      0  53.1000  C123        S
# 4            5         0       3  35.0      0      0   8.0500   NaN        S
#
#    gender
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1

# %%
temp2.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Cabin          687
# Embarked         2
# gender           0
# dtype: int64

# %%
temp2.Cabin.fillna(0,inplace = True)
temp2.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare Cabin Embarked  \
# 0            1         0       3  22.0      1      0   7.2500     0        S
# 1            2         1       1  38.0      1      0  71.2833   C85        C
# 2            3         1       3  26.0      0      0   7.9250     0        S
# 3            4         1       1  35.0      1      0  53.1000  C123        S
# 4            5         0       3  35.0      0      0   8.0500     0        S
#
#    gender
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1

# %%
a = temp2[temp2.Survived==1]
a
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare Cabin  \
# 1              2         1       1  38.0      1      0  71.2833   C85
# 2              3         1       3  26.0      0      0   7.9250     0
# 3              4         1       1  35.0      1      0  53.1000  C123
# 8              9         1       3  27.0      0      2  11.1333     0
# 9             10         1       2  14.0      1      0  30.0708     0
# ..           ...       ...     ...   ...    ...    ...      ...   ...
# 875          876         1       3  15.0      0      0   7.2250     0
# 879          880         1       1  56.0      0      1  83.1583   C50
# 880          881         1       2  25.0      0      1  26.0000     0
# 887          888         1       1  19.0      0      0  30.0000   B42
# 889          890         1       1  26.0      0      0  30.0000  C148
#
#     Embarked  gender
# 1          C       0
# 2          S       0
# 3          S       0
# 8          S       0
# 9          C       0
# ..       ...     ...
# 875        C       0
# 879        C       0
# 880        S       0
# 887        S       0
# 889        C       1
#
# [342 rows x 10 columns]

# %%
temp2.Age.fillna(a.Age.mean(),inplace = True)
temp2
# Out:
#      PassengerId  Survived  Pclass       Age  SibSp  Parch     Fare Cabin  \
# 0              1         0       3  22.00000      1      0   7.2500     0
# 1              2         1       1  38.00000      1      0  71.2833   C85
# 2              3         1       3  26.00000      0      0   7.9250     0
# 3              4         1       1  35.00000      1      0  53.1000  C123
# 4              5         0       3  35.00000      0      0   8.0500     0
# ..           ...       ...     ...       ...    ...    ...      ...   ...
# 886          887         0       2  27.00000      0      0  13.0000     0
# 887          888         1       1  19.00000      0      0  30.0000   B42
# 888          889         0       3  28.34369      1      2  23.4500     0
# 889          890         1       1  26.00000      0      0  30.0000  C148
# 890          891         0       3  32.00000      0      0   7.7500     0
#
#     Embarked  gender
# 0          S       1
# 1          C       0
# 2          S       0
# 3          S       0
# 4          S       1
# ..       ...     ...
# 886        S       1
# 887        S       0
# 888        S       0
# 889        C       1
# 890        Q       1
#
# [891 rows x 10 columns]

# %%
b = temp2[temp2.Survived==0]

temp2.Age.fillna(b.Age.mean(),inplace = True)

temp2
# Out:
#      PassengerId  Survived  Pclass       Age  SibSp  Parch     Fare Cabin  \
# 0              1         0       3  22.00000      1      0   7.2500     0
# 1              2         1       1  38.00000      1      0  71.2833   C85
# 2              3         1       3  26.00000      0      0   7.9250     0
# 3              4         1       1  35.00000      1      0  53.1000  C123
# 4              5         0       3  35.00000      0      0   8.0500     0
# ..           ...       ...     ...       ...    ...    ...      ...   ...
# 886          887         0       2  27.00000      0      0  13.0000     0
# 887          888         1       1  19.00000      0      0  30.0000   B42
# 888          889         0       3  28.34369      1      2  23.4500     0
# 889          890         1       1  26.00000      0      0  30.0000  C148
# 890          891         0       3  32.00000      0      0   7.7500     0
#
#     Embarked  gender
# 0          S       1
# 1          C       0
# 2          S       0
# 3          S       0
# 4          S       1
# ..       ...     ...
# 886        S       1
# 887        S       0
# 888        S       0
# 889        C       1
# 890        Q       1
#
# [891 rows x 10 columns]

# %%
temp2.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Cabin          0
# Embarked       2
# gender         0
# dtype: int64

# %% [markdown]
# temp2.Embarkment

# %%
temp2.Embarked
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
def e(n):
    if n == 'S':
        return 1
    else:
        return 0


temp2["southhampton"] = temp2.Embarked.apply(e)

temp2.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare Cabin Embarked  \
# 0            1         0       3  22.0      1      0   7.2500     0        S
# 1            2         1       1  38.0      1      0  71.2833   C85        C
# 2            3         1       3  26.0      0      0   7.9250     0        S
# 3            4         1       1  35.0      1      0  53.1000  C123        S
# 4            5         0       3  35.0      0      0   8.0500     0        S
#
#    gender  southhampton
# 0       1             1
# 1       0             0
# 2       0             1
# 3       0             1
# 4       1             1

# %%
def c(n):
    if n == 'C':
        return 1
    else:
        return 0


temp2["cherbourgh"] = temp2.Embarked.apply(c)

temp2.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare Cabin Embarked  \
# 0            1         0       3  22.0      1      0   7.2500     0        S
# 1            2         1       1  38.0      1      0  71.2833   C85        C
# 2            3         1       3  26.0      0      0   7.9250     0        S
# 3            4         1       1  35.0      1      0  53.1000  C123        S
# 4            5         0       3  35.0      0      0   8.0500     0        S
#
#    gender  southhampton  cherbourgh
# 0       1             1           0
# 1       0             0           1
# 2       0             1           0
# 3       0             1           0
# 4       1             1           0

# %%
def q(n):
    if n == 'Q':
        return 1
    else:
        return 0


temp2["queenstown"] = temp2.Embarked.apply(q)

temp2.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare Cabin Embarked  \
# 0            1         0       3  22.0      1      0   7.2500     0        S
# 1            2         1       1  38.0      1      0  71.2833   C85        C
# 2            3         1       3  26.0      0      0   7.9250     0        S
# 3            4         1       1  35.0      1      0  53.1000  C123        S
# 4            5         0       3  35.0      0      0   8.0500     0        S
#
#    gender  southhampton  cherbourgh  queenstown
# 0       1             1           0           0
# 1       0             0           1           0
# 2       0             1           0           0
# 3       0             1           0           0
# 4       1             1           0           0

# %%
del temp2["Embarked"]
temp2.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare Cabin  gender  \
# 0            1         0       3  22.0      1      0   7.2500     0       1
# 1            2         1       1  38.0      1      0  71.2833   C85       0
# 2            3         1       3  26.0      0      0   7.9250     0       0
# 3            4         1       1  35.0      1      0  53.1000  C123       0
# 4            5         0       3  35.0      0      0   8.0500     0       1
#
#    southhampton  cherbourgh  queenstown
# 0             1           0           0
# 1             0           1           0
# 2             1           0           0
# 3             1           0           0
# 4             1           0           0

# %%
temp2.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Age             0
# SibSp           0
# Parch           0
# Fare            0
# Cabin           0
# gender          0
# southhampton    0
# cherbourgh      0
# queenstown      0
# dtype: int64

# %%
temp2.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.429858    0.523008
# std     257.353842    0.486592    0.836071   13.013270    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.343690    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare      gender  southhampton  cherbourgh  \
# count  891.000000  891.000000  891.000000    891.000000  891.000000
# mean     0.381594   32.204208    0.647587      0.722783    0.188552
# std      0.806057   49.693429    0.477990      0.447876    0.391372
# min      0.000000    0.000000    0.000000      0.000000    0.000000
# 25%      0.000000    7.910400    0.000000      0.000000    0.000000
# 50%      0.000000   14.454200    1.000000      1.000000    0.000000
# 75%      0.000000   31.000000    1.000000      1.000000    0.000000
# max      6.000000  512.329200    1.000000      1.000000    1.000000
#
#        queenstown
# count  891.000000
# mean     0.086420
# std      0.281141
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      1.000000

# %%
temp2.to_csv("C://Users/ARPIT/Desktop/titanic/titanic_clean.csv")
